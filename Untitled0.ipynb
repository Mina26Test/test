# %% [markdown]
# <a href="https://colab.research.google.com/github/Mina26Test/test/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Once your Google Drive is mounted, you can access your files. For example, if you have a CSV file named `my_data.csv` in your Drive, you can load it into a pandas DataFrame like this:
#
# ```python
# import pandas as pd
# df = pd.read_csv('/content/drive/MyDrive/my_data.csv')
# display(df.head())
# ```
#
# Please replace `my_data.csv` with the actual path and filename of your data file in Google Drive. If your file is not a CSV, adjust the loading function accordingly (e.g., `pd.read_excel()` for Excel files).

# %%
import pandas as pd

# Assuming MOCK_DATA.csv is in the root of your Google Drive's 'My Drive' folder
file_path = '/content/drive/Shareddrives/testowyKacprowyDysk/MOCK_DATA.csv'

try:
    df_mock_data = pd.read_csv(file_path)
    print(f"Successfully loaded data from {file_path}")
    display(df_mock_data.head())
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found. Please check the file path and ensure your Google Drive is mounted correctly.")
except Exception as e:
    print(f"An error occurred while reading the CSV file: {e}")
# Out:
# Successfully loaded data from /content/drive/Shareddrives/testowyKacprowyDysk/MOCK_DATA.csv
#    id first_name  last_name                           email  gender  \
# 0   1    Cornela    Crocker              ccrocker0@1688.com  Female
# 1   2     Kasper    Conyers           kconyers1@samsung.com    Male
# 2   3      Janos  Muldowney  jmuldowney2@barnesandnoble.com    Male
# 3   4      Ailee   Eidelman        aeidelman3@wikimedia.org  Female
# 4   5    Cordula    Gooding         cgooding4@mediafire.com  Female
#
#         ip_address
# 0  150.145.141.239
# 1    53.47.162.128
# 2   154.15.117.137
# 3    11.87.143.181
# 4  117.175.232.165
